# %%
#Comparing generated json file when Normalization is True and False for knn_raw

# %%
"""
Experiment summary
------------------
Treat each province/state in a country cases over time
as a vector, do a simple K-Nearest Neighbor between 
countries. What country has the most similar trajectory
to a given country?
"""

import sys
sys.path.insert(0, '..')

from utils import data
import os
import sklearn
import numpy as np
from sklearn.neighbors import (
    KNeighborsClassifier,
    DistanceMetric
)
import json

# ------------ HYPERPARAMETERS -------------
BASE_PATH = '../COVID-19/csse_covid_19_data/'
N_NEIGHBORS = 5
MIN_CASES = 1000
NORMALIZE = False
# ------------------------------------------

confirmed = os.path.join(
    BASE_PATH, 
    'csse_covid_19_time_series',
    'time_series_covid19_confirmed_global.csv')
confirmed = data.load_csv_data(confirmed)
features = []
targets = []

for val in np.unique(confirmed["Country/Region"]):
    df = data.filter_by_attribute(
        confirmed, "Country/Region", val)
    cases, labels = data.get_cases_chronologically(df)
    features.append(cases)
    targets.append(labels)

features = np.concatenate(features, axis=0)
targets = np.concatenate(targets, axis=0)
predictions = {}

for _dist in ['minkowski', 'manhattan']:
    for val in np.unique(confirmed["Country/Region"]):
        # test data
        df = data.filter_by_attribute(
            confirmed, "Country/Region", val)
        cases, labels = data.get_cases_chronologically(df)

        # filter the rest of the data to get rid of the country we are
        # trying to predict
        mask = targets[:, 1] != val
        tr_features = features[mask]
        tr_targets = targets[mask][:, 1]

        above_min_cases = tr_features.sum(axis=-1) > MIN_CASES
        tr_features = tr_features[above_min_cases]
        if NORMALIZE:
            tr_features = tr_features / tr_features.sum(axis=-1, keepdims=True)
        tr_targets = tr_targets[above_min_cases]

        # train knn
        knn = KNeighborsClassifier(n_neighbors=N_NEIGHBORS, metric=_dist)
        knn.fit(tr_features, tr_targets)

        # predict
        cases = cases.sum(axis=0, keepdims=True)
        # nearest country to this one based on trajectory
        label = knn.predict(cases)
        
        if val not in predictions:
            predictions[val] = {}
        predictions[val][_dist] = label.tolist()

with open('results/knn_rawNormalizeFalse.json', 'w') as f:
    json.dump(predictions, f, indent=4)

# %%
"""
Experiment summary
------------------
Treat each province/state in a country cases over time
as a vector, do a simple K-Nearest Neighbor between 
countries. What country has the most similar trajectory
to a given country?
"""

import sys
sys.path.insert(0, '..')

from utils import data
import os
import sklearn
import numpy as np
from sklearn.neighbors import (
    KNeighborsClassifier,
    DistanceMetric
)
import json

# ------------ HYPERPARAMETERS -------------
BASE_PATH = '../COVID-19/csse_covid_19_data/'
N_NEIGHBORS = 5
MIN_CASES = 1000
NORMALIZE = True
# ------------------------------------------

confirmed = os.path.join(
    BASE_PATH, 
    'csse_covid_19_time_series',
    'time_series_covid19_confirmed_global.csv')
confirmed = data.load_csv_data(confirmed)
features = []
targets = []

for val in np.unique(confirmed["Country/Region"]):
    df = data.filter_by_attribute(
        confirmed, "Country/Region", val)
    cases, labels = data.get_cases_chronologically(df)
    features.append(cases)
    targets.append(labels)

features = np.concatenate(features, axis=0)
targets = np.concatenate(targets, axis=0)
predictions = {}

for _dist in ['minkowski', 'manhattan']:
    for val in np.unique(confirmed["Country/Region"]):
        # test data
        df = data.filter_by_attribute(
            confirmed, "Country/Region", val)
        cases, labels = data.get_cases_chronologically(df)

        # filter the rest of the data to get rid of the country we are
        # trying to predict
        mask = targets[:, 1] != val
        tr_features = features[mask]
        tr_targets = targets[mask][:, 1]

        above_min_cases = tr_features.sum(axis=-1) > MIN_CASES
        tr_features = tr_features[above_min_cases]
        if NORMALIZE:
            tr_features = tr_features / tr_features.sum(axis=-1, keepdims=True)
        tr_targets = tr_targets[above_min_cases]

        # train knn
        knn = KNeighborsClassifier(n_neighbors=N_NEIGHBORS, metric=_dist)
        knn.fit(tr_features, tr_targets)

        # predict
        cases = cases.sum(axis=0, keepdims=True)
        # nearest country to this one based on trajectory
        label = knn.predict(cases)
        
        if val not in predictions:
            predictions[val] = {}
        predictions[val][_dist] = label.tolist()

with open('results/knn_rawNormalizeTrue.json', 'w') as f:
    json.dump(predictions, f, indent=4)

# %%
import json

NormTrue = open('results/knn_rawNormalizeTrue.json',)
NormFalse = open('results/knn_rawNormalizeFalse.json',)

NormTrueData = json.load(NormTrue)
NormFalseData = json.load(NormFalse)


MinKowskicompare = {}
Manhattancompare = {}


for country in NormTrueData.keys():
    
    v1 = NormTrueData[country]
    v2 = NormFalseData[country]
    
    MinkowskiCountry1 = v1['minkowski'][0]
    ManhattanCountry1 = v1['manhattan'][0]
    
    MinkowskiCountry2 = v2['minkowski'][0]
    ManhattanCountry2 = v2['manhattan'][0]
    
    if (MinkowskiCountry1, MinkowskiCountry2) not in MinKowskicompare:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] = 1
        
    else:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] += 1
        
    if (ManhattanCountry1, ManhattanCountry2) not in Manhattancompare:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] = 1
        
    else:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] += 1
       
print("Comparing MinKowski Distance")    
print(MinKowskicompare)

print("Comparing Manhattan Distance")
print(Manhattancompare)

import operator
print(max(MinKowskicompare.items(), key=operator.itemgetter(1))[0])
print(max(MinKowskicompare.values()))
print(max(Manhattancompare.items(), key=operator.itemgetter(1))[0])
print(max(Manhattancompare.values()))
    
NumSameMinKowski = 0
NumDiffMinkiwski = 0
NumSameManhattan = 0
NumDiffManhattan = 0

for k in MinKowskicompare.keys():
    if k[0] == k[1]:
        NumSameMinKowski += MinKowskicompare[k]
    else:
        NumDiffMinkiwski += MinKowskicompare[k]
        
print("Number of countries with same result for Minkowski Distance")
print(NumSameMinKowski)

print("Number of countries with different result Minkowski Distance")
print(NumDiffMinkiwski)

for k in Manhattancompare.keys():
    if k[0] == k[1]:
        NumSameManhattan += Manhattancompare[k]
    else:
        NumDiffManhattan += Manhattancompare[k]    
    
print("Number of countries with same result for Manhattan Distance")
print(NumSameManhattan)

print("Number of countries with different result Manhattan Distance")
print(NumDiffManhattan)
# Out:
# Comparing MinKowski Distance
# {('Cambodia', 'Cameroon'): 2, ('Cambodia', 'Canada'): 22, ('Cambodia', 'Kenya'): 1, ('Cambodia', 'Belize'): 1, ('Cambodia', 'Cabo Verde'): 4, ('Cambodia', 'Bhutan'): 1, ('Cambodia', 'Colombia'): 2, ('Cambodia', 'Ethiopia'): 2, ('France', 'Congo (Kinshasa)'): 1, ('Cambodia', 'Japan'): 1, ('Cambodia', 'Costa Rica'): 1, ('Cambodia', 'Andorra'): 4, ('Cambodia', 'Bosnia and Herzegovina'): 2, ('Cambodia', 'Iraq'): 2, ('Cambodia', 'Burundi'): 2, ('Cambodia', 'Bolivia'): 3, ('France', 'Andorra'): 1, ('Cambodia', 'Gambia'): 1, ('Cambodia', 'Antigua and Barbuda'): 1, ('Cambodia', 'Belarus'): 6, ('Cambodia', 'Burma'): 1, ('Cambodia', 'France'): 9, ('Cambodia', 'China'): 5, ('Cambodia', 'Azerbaijan'): 5, ('France', 'Algeria'): 1, ('Cambodia', 'Barbados'): 5, ('Laos', 'Netherlands'): 1, ('Cambodia', "Cote d'Ivoire"): 1, ('Cambodia', 'Belgium'): 8, ('Cambodia', 'Australia'): 7, ('Cambodia', 'United Kingdom'): 5, ('Cambodia', 'Algeria'): 3, ('Cambodia', 'Argentina'): 6, ('Cambodia', 'Bahamas'): 3, ('Cambodia', 'Angola'): 4, ('Cambodia', 'Armenia'): 5, ('Cambodia', 'Madagascar'): 1, ('Cambodia', 'Estonia'): 1, ('Cambodia', 'Chile'): 1, ('Cambodia', 'Ireland'): 1, ('Central African Republic', 'China'): 1, ('Cambodia', 'Central African Republic'): 1, ('Cambodia', 'Guatemala'): 1, ('Cambodia', 'Afghanistan'): 4, ('Cambodia', 'Kosovo'): 1, ('Cambodia', 'Italy'): 1, ('Cambodia', 'Benin'): 3, ('Cambodia', 'Chad'): 3, ('Canada', 'Canada'): 2, ('Cambodia', 'Austria'): 5, ('Cambodia', 'Brazil'): 2, ('Cambodia', 'Czechia'): 3, ('Cambodia', 'Denmark'): 4, ('Cambodia', 'Albania'): 2, ('France', 'Burkina Faso'): 1, ('Cambodia', 'Comoros'): 1, ('Central African Republic', 'Canada'): 1, ('Cambodia', 'Bulgaria'): 1, ('Cambodia', 'Eswatini'): 1, ('France', 'Canada'): 2, ('Cambodia', 'Finland'): 2, ('France', 'Austria'): 1, ('Cambodia', 'Cyprus'): 1, ('Cambodia', 'Botswana'): 2, ('Cambodia', 'Bahrain'): 3, ('Cambodia', 'Bangladesh'): 1, ('Cambodia', 'Indonesia'): 1, ('Cambodia', 'Egypt'): 1, ('Cambodia', 'Ecuador'): 1, ('Cambodia', 'Congo (Kinshasa)'): 2, ('Cambodia', 'Congo (Brazzaville)'): 1, ('Cambodia', 'Hungary'): 1, ('Canada', 'China'): 2, ('Cambodia', 'Netherlands'): 1}
# Comparing Manhattan Distance
denmark', 'Bosnia and Herzegovina'): 1, ('Australia', 'Indonesia'): 1, ('Canada', 'Belgium'): 1, ('Canada', 'Egypt'): 1, ('Netherlands', 'Barbados'): 1, ('France', 'France'): 1, ('France', 'United Kingdom'): 1, ('Australia', 'Bangladesh'): 1, ('Burundi', 'Chad'): 1, ('Australia', 'Afghanistan'): 1, ('Canada', 'Guyana'): 1, ('Australia', 'Czechia'): 1, ('Bahamas', 'Israel'): 1, ('Belize', 'France'): 1, ('Fiji', 'Azerbaijan'): 1, ('China', 'Brazil'): 1, ('United Kingdom', 'Czechia'): 1, ('Central African Republic', 'Bahrain'): 1, ('China', 'Burundi'): 1, ('France', 'Denmark'): 1, ('Canada', 'Chad'): 1, ('Canada', 'Estonia'): 1}
# ('Cambodia', 'Canada')
# 22
# ('Canada', 'Canada')
# 12
# Number of countries with same result for Minkowski Distance
# 2
# Number of countries with different result Minkiwski Distance
# 191
# Number of countries with same result for Manhattan Distance
# 15
# Number of countries with different result Manhattan Distance
# 178

# %%
#Comparing generated json file when Normalization is True and False for knn_diff

# %%
"""
Experiment summary
------------------
Treat each province/state in a country cases over time
as a vector, do a simple K-Nearest Neighbor between 
countries. What country has the most similar trajectory
to a given country?

This one is different in that it uses the difference in cases
from day to day, rather than the raw number of cases.
"""

import sys
sys.path.insert(0, '..')

from utils import data
import os
import sklearn
import numpy as np
from sklearn.neighbors import (
    KNeighborsClassifier,
    DistanceMetric
)
import json

# ------------ HYPERPARAMETERS -------------
BASE_PATH = '../COVID-19/csse_covid_19_data/'
N_NEIGHBORS = 5
MIN_CASES = 1000
NORMALIZE = True
# ------------------------------------------

confirmed = os.path.join(
    BASE_PATH, 
    'csse_covid_19_time_series',
    'time_series_covid19_confirmed_global.csv')
confirmed = data.load_csv_data(confirmed)
features = []
targets = []

for val in np.unique(confirmed["Country/Region"]):
    df = data.filter_by_attribute(
        confirmed, "Country/Region", val)
    cases, labels = data.get_cases_chronologically(df)
    features.append(cases)
    targets.append(labels)

features = np.concatenate(features, axis=0)
targets = np.concatenate(targets, axis=0)
predictions = {}

for _dist in ['minkowski', 'manhattan']:
    for val in np.unique(confirmed["Country/Region"]):
        # test data
        df = data.filter_by_attribute(
            confirmed, "Country/Region", val)
        cases, labels = data.get_cases_chronologically(df)

        # filter the rest of the data to get rid of the country we are
        # trying to predict
        mask = targets[:, 1] != val
        tr_features = features[mask]
        tr_targets = targets[mask][:, 1]

        above_min_cases = tr_features.sum(axis=-1) > MIN_CASES
        tr_features = np.diff(tr_features[above_min_cases], axis=-1)
        if NORMALIZE:
            tr_features = tr_features / tr_features.sum(axis=-1, keepdims=True)

        tr_targets = tr_targets[above_min_cases]

        # train knn
        knn = KNeighborsClassifier(n_neighbors=N_NEIGHBORS, metric=_dist)
        knn.fit(tr_features, tr_targets)

        # predict
        cases = np.diff(cases.sum(axis=0, keepdims=True), axis=-1)
        # nearest country to this one based on trajectory
        label = knn.predict(cases)
        
        if val not in predictions:
            predictions[val] = {}
        predictions[val][_dist] = label.tolist()

with open('results/knnDiffNormalizeTrue.json', 'w') as f:
    json.dump(predictions, f, indent=4)

# %%
"""
Experiment summary
------------------
Treat each province/state in a country cases over time
as a vector, do a simple K-Nearest Neighbor between 
countries. What country has the most similar trajectory
to a given country?

This one is different in that it uses the difference in cases
from day to day, rather than the raw number of cases.
"""

import sys
sys.path.insert(0, '..')

from utils import data
import os
import sklearn
import numpy as np
from sklearn.neighbors import (
    KNeighborsClassifier,
    DistanceMetric
)
import json

# ------------ HYPERPARAMETERS -------------
BASE_PATH = '../COVID-19/csse_covid_19_data/'
N_NEIGHBORS = 5
MIN_CASES = 1000
NORMALIZE = False
# ------------------------------------------

confirmed = os.path.join(
    BASE_PATH, 
    'csse_covid_19_time_series',
    'time_series_covid19_confirmed_global.csv')
confirmed = data.load_csv_data(confirmed)
features = []
targets = []

for val in np.unique(confirmed["Country/Region"]):
    df = data.filter_by_attribute(
        confirmed, "Country/Region", val)
    cases, labels = data.get_cases_chronologically(df)
    features.append(cases)
    targets.append(labels)

features = np.concatenate(features, axis=0)
targets = np.concatenate(targets, axis=0)
predictions = {}

for _dist in ['minkowski', 'manhattan']:
    for val in np.unique(confirmed["Country/Region"]):
        # test data
        df = data.filter_by_attribute(
            confirmed, "Country/Region", val)
        cases, labels = data.get_cases_chronologically(df)

        # filter the rest of the data to get rid of the country we are
        # trying to predict
        mask = targets[:, 1] != val
        tr_features = features[mask]
        tr_targets = targets[mask][:, 1]

        above_min_cases = tr_features.sum(axis=-1) > MIN_CASES
        tr_features = np.diff(tr_features[above_min_cases], axis=-1)
        if NORMALIZE:
            tr_features = tr_features / tr_features.sum(axis=-1, keepdims=True)

        tr_targets = tr_targets[above_min_cases]

        # train knn
        knn = KNeighborsClassifier(n_neighbors=N_NEIGHBORS, metric=_dist)
        knn.fit(tr_features, tr_targets)

        # predict
        cases = np.diff(cases.sum(axis=0, keepdims=True), axis=-1)
        # nearest country to this one based on trajectory
        label = knn.predict(cases)
        
        if val not in predictions:
            predictions[val] = {}
        predictions[val][_dist] = label.tolist()

with open('results/knnDiffNormalizeFalse.json', 'w') as f:
    json.dump(predictions, f, indent=4)

# %%
import json

NormTrue = open('results/knnDiffNormalizeTrue.json',)
NormFalse = open('results/knnDiffNormalizeFalse.json',)

NormTrueData = json.load(NormTrue)
NormFalseData = json.load(NormFalse)


MinKowskicompare = {}
Manhattancompare = {}


for country in NormTrueData.keys():
    
    v1 = NormTrueData[country]
    v2 = NormFalseData[country]
    
    MinkowskiCountry1 = v1['minkowski'][0]
    ManhattanCountry1 = v1['manhattan'][0]
    
    MinkowskiCountry2 = v2['minkowski'][0]
    ManhattanCountry2 = v2['manhattan'][0]
    
    if (MinkowskiCountry1, MinkowskiCountry2) not in MinKowskicompare:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] = 1
        
    else:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] += 1
        
    if (ManhattanCountry1, ManhattanCountry2) not in Manhattancompare:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] = 1
        
    else:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] += 1
       
print("Comparing MinKowski Distance")    
print(MinKowskicompare)

print("Comparing Manhattan Distance")
print(Manhattancompare)

import operator
print(max(MinKowskicompare.items(), key=operator.itemgetter(1))[0])
print(max(MinKowskicompare.values()))
print(max(Manhattancompare.items(), key=operator.itemgetter(1))[0])
print(max(Manhattancompare.values()))


NumSameMinKowski = 0
NumDiffMinkiwski = 0
NumSameManhattan = 0
NumDiffManhattan = 0

for k in MinKowskicompare.keys():
    if k[0] == k[1]:
        NumSameMinKowski += MinKowskicompare[k]
    else:
        NumDiffMinkiwski += MinKowskicompare[k]
        
print("Number of countries with same result for Minkowski Distance")
print(NumSameMinKowski)

print("Number of countries with different result Minkowski Distance")
print(NumDiffMinkiwski)

for k in Manhattancompare.keys():
    if k[0] == k[1]:
        NumSameManhattan += Manhattancompare[k]
    else:
        NumDiffManhattan += Manhattancompare[k]    
    
print("Number of countries with same result for Manhattan Distance")
print(NumSameManhattan)

print("Number of countries with different result Manhattan Distance")
print(NumDiffManhattan)
# Out:
# Comparing MinKowski Distance
# {('Central African Republic', 'Congo (Kinshasa)'): 1, ('Antigua and Barbuda', 'Estonia'): 1, ('Canada', 'Canada'): 5, ('Burma', 'Chad'): 1, ('Fiji', 'Cabo Verde'): 1, ('France', 'United Kingdom'): 2, ('Cambodia', 'Colombia'): 2, ('Belgium', 'Bosnia and Herzegovina'): 1, ('China', 'China'): 3, ('Canada', 'Bulgaria'): 2, ('Canada', 'Croatia'): 1, ('France', 'Netherlands'): 1, ('Fiji', 'Cuba'): 1, ('Djibouti', 'Ethiopia'): 1, ('Antigua and Barbuda', 'Antigua and Barbuda'): 1, ('Armenia', 'Austria'): 1, ('Burma', 'China'): 1, ('France', 'France'): 2, ('Denmark', 'Australia'): 1, ('Fiji', 'Bahrain'): 3, ('Bulgaria', 'Armenia'): 1, ('Antigua and Barbuda', 'Canada'): 1, ('France', 'Argentina'): 1, ('Australia', 'Australia'): 6, ('Canada', 'Bosnia and Herzegovina'): 2, ('China', 'United Kingdom'): 1, ('Belize', 'Algeria'): 1, ('Cambodia', 'Antigua and Barbuda'): 1, ('Cambodia', 'Angola'): 1, ('Fiji', 'Angola'): 3, ('Netherlands', 'Netherlands'): 1, ('United Kingdom', 'Japan'): 1, ('Afghanistan', 'Canada'): 1, ('China', 'Canada'): 7, ('Cambodia', 'Bangladesh'): 3, ('Australia', 'Burkina Faso'): 1, ('Cambodia', 'Argentina'): 2, ('United Kingdom', 'Burundi'): 1, ('United Kingdom', 'Burkina Faso'): 1, ('Canada', 'Bahrain'): 1, ('France', 'Congo (Kinshasa)'): 1, ('Belize', 'Azerbaijan'): 1, ('Cambodia', 'Estonia'): 1, ('Australia', 'Canada'): 4, ('France', 'Belgium'): 1, ('United Kingdom', 'Belarus'): 2, ('Cameroon', 'Burundi'): 1, ('Barbados', 'Canada'): 2, ('China', 'Egypt'): 1, ('Cambodia', 'Belarus'): 1, ('Cambod
Canada'): 1, ('Botswana', 'Burkina Faso'): 1, ('Djibouti', 'Czechia'): 1, ('Belize', 'Estonia'): 1, ('France', 'Antigua and Barbuda'): 2, ('Canada', 'Cambodia'): 2, ('Netherlands', 'Burma'): 1, ('Canada', 'Malawi'): 2, ('Botswana', 'Armenia'): 1, ('Andorra', 'Belgium'): 1, ('United Kingdom', 'United Kingdom'): 2, ('Cabo Verde', 'Albania'): 1, ('Australia', 'Afghanistan'): 1, ('United Kingdom', 'Bangladesh'): 1, ('Belize', 'Denmark'): 1, ('United Kingdom', 'France'): 1, ('Botswana', 'Ethiopia'): 1, ('Belize', 'Bangladesh'): 1, ('Canada', 'Czechia'): 2, ('Antigua and Barbuda', 'Austria'): 1, ('Belize', 'Afghanistan'): 1, ('Belize', 'Austria'): 1, ('Canada', 'Colombia'): 1, ('Burundi', 'Burkina Faso'): 1, ('Barbados', 'Canada'): 1, ('France', 'United Kingdom'): 1, ('Barbados', 'Egypt'): 1, ('Cabo Verde', 'Congo (Kinshasa)'): 1, ('France', 'France'): 1, ('Comoros', 'United Kingdom'): 1, ('Cabo Verde', 'Australia'): 1, ('Netherlands', 'Denmark'): 1, ('France', 'Bangladesh'): 1, ('United Kingdom', 'Cuba'): 1, ('Belize', 'China'): 1, ('Canada', 'Burundi'): 1, ('Canada', 'Bulgaria'): 1, ('Australia', 'China'): 1, ('United Kingdom', 'Canada'): 1, ('Canada', 'Germany'): 2, ('Azerbaijan', 'Brazil'): 1, ('Canada', 'Andorra'): 1, ('Canada', 'Indonesia'): 1, ('Belize', 'Belarus'): 1, ('Bahamas', 'Cuba'): 1, ('Canada', 'Bhutan'): 1, ('Canada', 'Bosnia and Herzegovina'): 1, ('Cambodia', 'United Kingdom'): 1, ('Cambodia', 'Burkina Faso'): 1}
# ('China', 'Canada')
# 7
# ('Canada', 'Canada')
# 17
# Number of countries with same result for Minkowski Distance
# 20
# Number of countries with different result Minkowski Distance
# 173
# Number of countries with same result for Manhattan Distance
# 22
# Number of countries with different result Manhattan Distance
# 171

# %%
#Comparing result between knn_raw.py and knn_diff.py

# %%
import json

knnRaw = open('results/knn_rawNormalizeTrue.json',)
knnDiff = open('results/knnDiffNormalizeTrue.json',)

knnRawData = json.load(knnRaw)
knnDiffData = json.load(knnDiff)


MinKowskicompare = {}
Manhattancompare = {}


for country in knnRawData.keys():
    
    v1 = knnRawData[country]
    v2 = knnDiffData[country]
    
    MinkowskiCountry1 = v1['minkowski'][0]
    ManhattanCountry1 = v1['manhattan'][0]
    
    MinkowskiCountry2 = v2['minkowski'][0]
    ManhattanCountry2 = v2['manhattan'][0]
    
    if (MinkowskiCountry1, MinkowskiCountry2) not in MinKowskicompare:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] = 1
        
    else:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] += 1
        
    if (ManhattanCountry1, ManhattanCountry2) not in Manhattancompare:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] = 1
        
    else:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] += 1
       
print("Comparing MinKowski Distance")    
print(MinKowskicompare)

print("Comparing Manhattan Distance")
print(Manhattancompare)

import operator
print(max(MinKowskicompare.items(), key=operator.itemgetter(1))[0])
print(max(MinKowskicompare.values()))
print(max(Manhattancompare.items(), key=operator.itemgetter(1))[0])
print(max(Manhattancompare.values()))

NumSameMinKowski = 0
NumDiffMinkiwski = 0
NumSameManhattan = 0
NumDiffManhattan = 0

for k in MinKowskicompare.keys():
    if k[0] == k[1]:
        NumSameMinKowski += MinKowskicompare[k]
    else:
        NumDiffMinkiwski += MinKowskicompare[k]
        
print("Number of countries with same result for Minkowski Distance")
print(NumSameMinKowski)

print("Number of countries with different result Minkowski Distance")
print(NumDiffMinkiwski)

for k in Manhattancompare.keys():
    if k[0] == k[1]:
        NumSameManhattan += Manhattancompare[k]
    else:
        NumDiffManhattan += Manhattancompare[k]    
    
print("Number of countries with same result for Manhattan Distance")
print(NumSameManhattan)

print("Number of countries with different result Manhattan Distance")
print(NumDiffManhattan)
# Out:
# Comparing MinKowski Distance
# {('Cambodia', 'Central African Republic'): 3, ('Cambodia', 'Antigua and Barbuda'): 5, ('Cambodia', 'Canada'): 20, ('Cambodia', 'Burma'): 2, ('Cambodia', 'Fiji'): 12, ('Cambodia', 'France'): 24, ('Cambodia', 'Cambodia'): 25, ('Cambodia', 'Belgium'): 1, ('France', 'China'): 3, ('Cambodia', 'Djibouti'): 1, ('Cambodia', 'Armenia'): 1, ('France', 'Burma'): 1, ('Cambodia', 'Denmark'): 1, ('Cambodia', 'Bulgaria'): 3, ('Cambodia', 'Australia'): 12, ('Cambodia', 'China'): 26, ('France', 'Belize'): 2, ('Laos', 'Fiji'): 1, ('Cambodia', 'Netherlands'): 5, ('Cambodia', 'United Kingdom'): 15, ('Cambodia', 'Afghanistan'): 3, ('Cambodia', 'Belize'): 3, ('Central African Republic', 'China'): 1, ('Cambodia', 'Cameroon'): 4, ('Cambodia', 'Barbados'): 2, ('Cambodia', 'Comoros'): 2, ('Cambodia', 'Croatia'): 1, ('Canada', 'Australia'): 2, ('Cambodia', 'Austria'): 1, ('Cambodia', 'Maldives'): 1, ('Central African Republic', 'Australia'): 1, ('Canada', 'Burma'): 1, ('Cambodia', 'Grenada'): 1, ('France', 'Barbados'): 1, ('Cambodia', 'Azerbaijan'): 1, ('Cambodia', 'Papua New Guinea'): 1, ('Cambodia', 'Czechia'): 1, ('Cambodia', 'Botswana'): 1, ('Canada', 'Afghanistan'): 1, ('Cambodia', 'Benin'): 1}
# Comparing Manhattan Distance
# {('Australia', 'Canada'): 9, ('Canada', 'Canada'): 39, ('Comoros', 'France'): 1, ('Canada', 'United Kingdom'): 6, ('France', 'Belize'): 5, ('Canada', 'Netherlands'): 3, ('Canada', "Cote d'Ivoire"): 1, ('Holy See', 'Belize'): 1, ('Canada', 'Australia'): 12, ('Australia', 'Australia'): 3, ('Brunei', 'Canada'): 1, ('France', 'Canada'): 7, ('France', 'United Kingdom'): 2, ('Canada', 'Central African Republic'): 1, ('Canada', 'Cambodia'): 4, ('MS Zaandam', 'Canada'): 2, ('Denmark', 'Canada'): 1, ('United Kingdom', 'France'): 2, ('Botswana', 'Belize'): 1, ('Grenada', 'Canada'): 1, ('France', 'Burma'): 2, ('Fiji', 'France'): 3, ('Canada', 'Gabon'): 1, ('France', 'France'): 5, ('Fiji', 'Brunei'): 1, ('United Kingdom', 'China'): 1, ('United Kingdom', 'Canada'): 4, ('France', 'Comoros'): 1, ('France', 'Netherlands'): 3, ('Canada', 'Botswana'): 3, ('Canada', 'Burma'): 1, ('Canada', 'Benin'): 1, ('Dominica', 'Australia'): 1, ('United Kingdom', 'United Kingdom'): 1, ('France', 'Antigua and Barbuda'): 1, ('Denmark', 'Australia'): 2, ('Australia', 'France'): 2, ('Cameroon', 'Andorra'): 1, ('Australia', 'Eswatini'): 1, ('Fiji', 'Canada'): 2, ('Brunei', 'Dominica'): 1, ('China', 'Australia'): 1, ('MS Zaandam', 'United Kingdom'): 1, ('Canada', 'Dominica'): 1, ('Dominica', 'Canada'): 3, ('Cambodia', 'France'): 1, ('Canada', 'Fiji'): 1, ('Canada', 'France'): 9, ('Benin', 'Australia'): 1, ('Denmark', 'Belize'): 1, ('United Kingdom', 'Australia'): 1, ('France', 'Brunei'): 1, ('Canada', 'Belgium'): 1, ('Australia', 'Djibouti'): 1, ('France', 'China'): 1, ('Fiji', 'Belize'): 1, ('France', 'Andorra'): 1, ('Botswana', 'United Kingdom'): 1, ('Australia', 'Cabo Verde'): 2, ('France', 'Australia'): 1, ('Brunei', 'United Kingdom'): 1, ('Canada', 'Belize'): 3, ('Denmark', 'Botswana'): 1, ('Brunei', 'Belize'): 1, ('Canada', 'Antigua and Barbuda'): 2, ('Canada', 'Burundi'): 1, ('Netherlands', 'Canada'): 1, ('Canada', 'Barbados'): 1, ('Australia', 'Barbados'): 1, ('Canada', 'Cabo Verde'): 1, ('Burundi', 'Comoros'): 1, ('Australia', 'United Kingdom'): 1, ('United Kingdom', 'Belize'): 1, ('Bahamas', 'Canada'): 1, ('Belize', 'Cambodia'): 1, ('Fiji', 'United Kingdom'): 1, ('China', 'Azerbaijan'): 1, ('Canada', 'Bahamas'): 1, ('Central African Republic', 'Canada'): 1, ('China', 'Canada'): 1}
# ('Cambodia', 'China')
# 26
# ('Canada', 'Canada')
# 39
# Number of countries with same result for Minkowski Distance
# 25
# Number of countries with different result Minkowski Distance
# 168
# Number of countries with same result for Manhattan Distance
# 48
# Number of countries with different result Manhattan Distance
# 145

# %%
#Does Doubleing number of nearest neighbors from 5 to 10 affect result for knn_diff.py

# %%
"""
Experiment summary
------------------
Treat each province/state in a country cases over time
as a vector, do a simple K-Nearest Neighbor between 
countries. What country has the most similar trajectory
to a given country?

This one is different in that it uses the difference in cases
from day to day, rather than the raw number of cases.
"""

import sys
sys.path.insert(0, '..')

from utils import data
import os
import sklearn
import numpy as np
from sklearn.neighbors import (
    KNeighborsClassifier,
    DistanceMetric
)
import json

# ------------ HYPERPARAMETERS -------------
BASE_PATH = '../COVID-19/csse_covid_19_data/'
N_NEIGHBORS = 10
MIN_CASES = 1000
NORMALIZE = True
# ------------------------------------------

confirmed = os.path.join(
    BASE_PATH, 
    'csse_covid_19_time_series',
    'time_series_covid19_confirmed_global.csv')
confirmed = data.load_csv_data(confirmed)
features = []
targets = []

for val in np.unique(confirmed["Country/Region"]):
    df = data.filter_by_attribute(
        confirmed, "Country/Region", val)
    cases, labels = data.get_cases_chronologically(df)
    features.append(cases)
    targets.append(labels)

features = np.concatenate(features, axis=0)
targets = np.concatenate(targets, axis=0)
predictions = {}

for _dist in ['minkowski', 'manhattan']:
    for val in np.unique(confirmed["Country/Region"]):
        # test data
        df = data.filter_by_attribute(
            confirmed, "Country/Region", val)
        cases, labels = data.get_cases_chronologically(df)

        # filter the rest of the data to get rid of the country we are
        # trying to predict
        mask = targets[:, 1] != val
        tr_features = features[mask]
        tr_targets = targets[mask][:, 1]

        above_min_cases = tr_features.sum(axis=-1) > MIN_CASES
        tr_features = np.diff(tr_features[above_min_cases], axis=-1)
        if NORMALIZE:
            tr_features = tr_features / tr_features.sum(axis=-1, keepdims=True)

        tr_targets = tr_targets[above_min_cases]

        # train knn
        knn = KNeighborsClassifier(n_neighbors=N_NEIGHBORS, metric=_dist)
        knn.fit(tr_features, tr_targets)

        # predict
        cases = np.diff(cases.sum(axis=0, keepdims=True), axis=-1)
        # nearest country to this one based on trajectory
        label = knn.predict(cases)
        
        if val not in predictions:
            predictions[val] = {}
        predictions[val][_dist] = label.tolist()

with open('results/knnDiffNormalizeTrue10.json', 'w') as f:
    json.dump(predictions, f, indent=4)

# %%
import json

knnDiff = open('results/knnDiffNormalizeTrue.json',)
knnDiff10 = open('results/knnDiffNormalizeTrue10.json',)

knnDiffData = json.load(knnDiff)
knnDiff10Data = json.load(knnDiff10)


MinKowskicompare = {}
Manhattancompare = {}


for country in knnDiffData.keys():
    
    v1 = knnDiffData[country]
    v2 = knnDiff10Data[country]
    
    MinkowskiCountry1 = v1['minkowski'][0]
    ManhattanCountry1 = v1['manhattan'][0]
    
    MinkowskiCountry2 = v2['minkowski'][0]
    ManhattanCountry2 = v2['manhattan'][0]
    
    if (MinkowskiCountry1, MinkowskiCountry2) not in MinKowskicompare:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] = 1
        
    else:
        MinKowskicompare[(MinkowskiCountry1, MinkowskiCountry2)] += 1
        
    if (ManhattanCountry1, ManhattanCountry2) not in Manhattancompare:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] = 1
        
    else:
        Manhattancompare[(ManhattanCountry1, ManhattanCountry2)] += 1
       
print("Comparing MinKowski Distance")    
print(MinKowskicompare)

print("Comparing Manhattan Distance")
print(Manhattancompare)

import operator
print(max(MinKowskicompare.items(), key=operator.itemgetter(1))[0])
print(max(MinKowskicompare.values()))
print(max(Manhattancompare.items(), key=operator.itemgetter(1))[0])
print(max(Manhattancompare.values()))

NumSameMinKowski = 0
NumDiffMinkiwski = 0
NumSameManhattan = 0
NumDiffManhattan = 0

for k in MinKowskicompare.keys():
    if k[0] == k[1]:
        NumSameMinKowski += MinKowskicompare[k]
    else:
        NumDiffMinkiwski += MinKowskicompare[k]
        
print("Number of countries with same result for Minkowski Distance")
print(NumSameMinKowski)

print("Number of countries with different result Minkowski Distance")
print(NumDiffMinkiwski)

for k in Manhattancompare.keys():
    if k[0] == k[1]:
        NumSameManhattan += Manhattancompare[k]
    else:
        NumDiffManhattan += Manhattancompare[k]    
    
print("Number of countries with same result for Manhattan Distance")
print(NumSameManhattan)

print("Number of countries with different result Manhattan Distance")
print(NumDiffManhattan)
# Out:
# Comparing MinKowski Distance
# {('Central African Republic', 'Cambodia'): 1, ('Antigua and Barbuda', 'Antigua and Barbuda'): 2, ('Canada', 'Canada'): 9, ('Burma', 'Belgium'): 1, ('Fiji', 'Cambodia'): 10, ('France', 'France'): 21, ('Cambodia', 'Cambodia'): 17, ('Belgium', 'Austria'): 1, ('China', 'China'): 24, ('Canada', 'Bulgaria'): 1, ('Canada', 'United Kingdom'): 3, ('France', 'Canada'): 2, ('Djibouti', 'Cameroon'): 1, ('Antigua and Barbuda', 'France'): 3, ('Armenia', 'France'): 1, ('Burma', 'Azerbaijan'): 1, ('Denmark', 'Cambodia'): 1, ('Bulgaria', 'Botswana'): 1, ('Australia', 'Australia'): 9, ('Canada', 'France'): 3, ('Belize', 'Canada'): 2, ('Cambodia', 'Canada'): 4, ('Fiji', 'Canada'): 1, ('Netherlands', 'France'): 1, ('United Kingdom', 'United Kingdom'): 11, ('Afghanistan', 'Afghanistan'): 4, ('Australia', 'United Kingdom'): 2, ('United Kingdom', 'Canada'): 1, ('Canada', 'Cambodia'): 2, ('Cameroon', 'Cameroon'): 1, ('Barbados', 'France'): 1, ('Cambodia', 'Netherlands'): 2, ('Australia', 'China'): 1, ('Central African Republic', 'France'): 1, ('Comoros', 'Barbados'): 2, ('France', 'Cameroon'): 1, ('Cameroon', 'Belgium'): 1, ('Croatia', 'Netherlands'): 1, ('Netherlands', 'Netherlands'): 4, ('United Kingdom', 'Australia'): 1, ('Cameroon', 'France'): 1, ('Cambodia', 'United Kingdom'): 2, ('China', 'United Kingdom'): 2, ('Austria', 'Austria'): 1, ('Bulgaria', 'Bulgaria'): 1, ('Maldives', 'Canada'): 1, ('Australia', 'Algeria'): 1, ('China', 'France'): 1, ('Belize', 'Afghanistan'): 1, ('Burma', 'United Kingdom'): 1, ('Burma', 'Australia'): 1, ('Belize', 'Austria'): 1, ('China', 'Barbados'): 1, ('Fiji', 'Bhutan'): 2, ('Grenada', 'United Kingdom'): 1, ('Australia', 'Afghanistan'): 1, ('Bulgaria', 'Azerbaijan'): 1, ('United Kingdom', 'Netherlands'): 1, ('Canada', 'Austria'): 2, ('Barbados', 'Barbados'): 1, ('United Kingdom', 'France'): 1, ('Central African Republic', 'Afghanistan'): 1, ('Barbados', 'Antigua and Barbuda'): 1, ('Azerbaijan', 'Canada'): 1, ('Papua New Guinea', 'Canada'): 1, ('Czechia', 'United Kingdom'): 1, ('Botswana', 'China'): 1, ('Australia', 'Canada'): 1, ('Belize', 'Belize'): 1, ('China', 'Antigua and Barbuda'): 1, ('China', 'Burkina Faso'): 1, ('Benin', 'Benin'): 1, ('Cameroon', 'United Kingdom'): 1}
# Comparing Manhattan Distance
# {('Canada', 'Canada'): 41, ('France', 'France'): 16, ('United Kingdom', 'United Kingdom'): 8, ('Belize', 'United Kingdom'): 3, ('Netherlands', 'Netherlands'): 4, ("Cote d'Ivoire", 'Australia'): 1, ('Belize', 'Bahamas'): 1, ('Australia', 'France'): 1, ('Australia', 'Netherlands'): 2, ('Canada', 'France'): 10, ('United Kingdom', 'Canada'): 5, ('Central African Republic', 'France'): 1, ('Cambodia', 'Cambodia'): 3, ('Canada', 'United Kingdom'): 5, ('Canada', 'Australia'): 8, ('Australia', 'Canada'): 2, ('Belize', 'Canada'): 5, ('Belize', 'Belize'): 3, ('Burma', 'Barbados'): 1, ('Australia', 'Australia'): 16, ('Burma', 'Burma'): 1, ('Gabon', 'Australia'): 1, ('United Kingdom', 'Netherlands'): 1, ('France', 'Denmark'): 1, ('Brunei', 'Canada'): 1, ('China', 'China'): 2, ('Comoros', 'Canada'): 1, ('Netherlands', 'Canada'): 2, ('Botswana', 'France'): 2, ('Burma', 'France'): 1, ('France', 'Canada'): 3, ('Benin', 'Benin'): 1, ('Australia', 'United Kingdom'): 1, ('Canada', 'Botswana'): 1, ('Antigua and Barbuda', 'France'): 1, ('France', 'United Kingdom'): 2, ('Andorra', 'Andorra'): 2, ('Eswatini', 'Australia'): 1, ('Canada', 'Belize'): 1, ('Dominica', 'Canada'): 1, ('Dominica', 'United Kingdom'): 1, ('France', 'Cameroon'): 1, ('Belize', 'Netherlands'): 2, ('Canada', 'Cambodia'): 1, ('Fiji', 'Cambodia'): 1, ('Canada', 'Netherlands'): 1, ('Cambodia', 'Australia'): 1, ('Canada', 'Antigua and Barbuda'): 1, ('Brunei', 'Belize'): 1, ('Belgium', 'China'): 1, ('Djibouti', 'Canada'): 1, ('Canada', 'Burundi'): 1, ('Botswana', 'Belize'): 1, ('Cabo Verde', 'Canada'): 2, ('Botswana', 'Canada'): 1, ('Antigua and Barbuda', 'Canada'): 1, ('Burundi', 'Canada'): 1, ('Barbados', 'Barbados'): 1, ('Antigua and Barbuda', 'Antigua and Barbuda'): 1, ('Barbados', 'United Kingdom'): 1, ('Cabo Verde', 'Netherlands'): 1, ('Comoros', 'Comoros'): 1, ('Canada', 'Burma'): 1, ('Azerbaijan', 'United Kingdom'): 1, ('Canada', 'Bahamas'): 2, ('Bahamas', 'United Kingdom'): 1, ('Cambodia', 'France'): 1}
# ('China', 'China')
# 24
# ('Canada', 'Canada')
# 41
# Number of countries with same result for Minkowski Distance
# 107
# Number of countries with different result Minkowski Distance
# 86
# Number of countries with same result for Manhattan Distance
# 100
# Number of countries with different result Manhattan Distance
# 93
